# %% [markdown]
# <h1>Содержание:<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Шаг-1.-Загрузим-данные-и-подготовим-их-к-анализу" data-toc-modified-id="Шаг-1.-Загрузим-данные-и-подготовим-их-к-анализу-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Шаг 1. Загрузим данные и подготовим их к анализу</a></span></li><li><span><a href="#Шаг-2.-Выполним-предобработку-данных" data-toc-modified-id="Шаг-2.-Выполним-предобработку-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Шаг 2. Выполним предобработку данных</a></span><ul class="toc-item"><li><span><a href="#Изучим-уникальные-значения-и-устраним-дубликаты" data-toc-modified-id="Изучим-уникальные-значения-и-устраним-дубликаты-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Изучим уникальные значения и устраним дубликаты</a></span></li><li><span><a href="#Поработаем-с-пропущенными-значениями" data-toc-modified-id="Поработаем-с-пропущенными-значениями-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Поработаем с пропущенными значениями</a></span></li><li><span><a href="#Поработаем-с-типом-данных" data-toc-modified-id="Поработаем-с-типом-данных-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Поработаем с типом данных</a></span></li><li><span><a href="#Добавим-в-таблицу-новые-столбцы" data-toc-modified-id="Добавим-в-таблицу-новые-столбцы-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Добавим в таблицу новые столбцы</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Шаг-3.-Анализ-данных" data-toc-modified-id="Шаг-3.-Анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Шаг 3. Анализ данных</a></span><ul class="toc-item"><li><span><a href="#RFM-анализ" data-toc-modified-id="RFM-анализ-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>RFM-анализ</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Recency" data-toc-modified-id="Recency-3.1.0.1"><span class="toc-item-num">3.1.0.1&nbsp;&nbsp;</span>Recency</a></span></li><li><span><a href="#Frequency" data-toc-modified-id="Frequency-3.1.0.2"><span class="toc-item-num">3.1.0.2&nbsp;&nbsp;</span>Frequency</a></span></li><li><span><a href="#Monetary" data-toc-modified-id="Monetary-3.1.0.3"><span class="toc-item-num">3.1.0.3&nbsp;&nbsp;</span>Monetary</a></span></li></ul></li><li><span><a href="#Сводная-таблица-по-сегментам" data-toc-modified-id="Сводная-таблица-по-сегментам-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Сводная таблица по сегментам</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Когортный-анализ" data-toc-modified-id="Когортный-анализ-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Когортный анализ</a></span><ul class="toc-item"><li><span><a href="#Retention-Rate" data-toc-modified-id="Retention-Rate-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Retention Rate</a></span></li><li><span><a href="#ARPU" data-toc-modified-id="ARPU-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>ARPU</a></span></li><li><span><a href="#LTV" data-toc-modified-id="LTV-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>LTV</a></span></li></ul></li><li><span><a href="#Маркетинговый-анализ" data-toc-modified-id="Маркетинговый-анализ-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Маркетинговый анализ</a></span><ul class="toc-item"><li><span><a href="#Маркетинговые-показатели:" data-toc-modified-id="Маркетинговые-показатели:-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Маркетинговые показатели:</a></span></li><li><span><a href="#Дополнительно" data-toc-modified-id="Дополнительно-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Дополнительно</a></span></li></ul></li></ul></li><li><span><a href="#Общие-выводы,-важное" data-toc-modified-id="Общие-выводы,-важное-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Общие выводы, важное</a></span><ul class="toc-item"><li><span><a href="#RFM" data-toc-modified-id="RFM-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>RFM</a></span></li><li><span><a href="#Когортный-анализ-и-Маркетинговый-анализ" data-toc-modified-id="Когортный-анализ-и-Маркетинговый-анализ-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Когортный анализ и Маркетинговый анализ</a></span></li><li><span><a href="#Дополнительно" data-toc-modified-id="Дополнительно-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Дополнительно</a></span></li></ul></li><li><span><a href="#Аналитическая панель" data-toc-modified-id="Аналитическая панель-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Аналитическая панель</a></span></li></ul></div>

# %% [markdown]
# # Анализ фандрайзинговой деятельности АНО «Простые вещи»

# %% [markdown]
# **Описание компании:**
# Инклюзивные мастерские «Простые вещи» — это мастерские (столярная, швейная, керамическая, дизайн-бюро, кулинарная, арт-студия, цветочная), в которых трудятся взрослые люди с ментальными особенностями.
#
# Задача «Простых вещей» — сделать всё возможное, чтобы люди с ментальными особенностями чувствовали себя частью общества, работали, общались и жили нормальную жизнь.
#
# **Задача:**
# «Простые вещи» хотят усовершенствовать фандрайзинг организации – лучше понимать лояльную аудиторию, кто покупает продукцию мастерских, кто оставляет пожертвования, понять, как лучше выстраивать коммуникацию с этими целевыми аудиториями.
#
# **Цель данного исследования:**
# 1. провести RFM-анализ, когортный анализ, маркетинговый анализ.
# 2. разработать аналитическую панель (dashboard), которая будет содержать информацию о поведении пользователей и их лояльности к «Простые вещи».
#
# **Ход исследования:**
# Данные мы получим из файла 'payments.xlsx'.
#
# Мы проверим данные на ошибки и оценим их влияние на исследование. Затем, на этапе предобработки мы поищем возможность исправить все ошибки данных, которые не приведут к искажению конечного результата. Далее приступим к проведению исследовательского анализа.
#
# Таким образом наше исследоваание пройдёт в пять этапов:
#
# - Шаг 1: Обзор данных.
# - Шаг 2: Предобработка данных.
# - Шаг 3: Анализ данных.
#     - RFM-анализ.
#     - Когортный анализ.
#     - Маркетинговый анализ.
# - Шаг 4: Написание общего вывода.
# - Шаг 5: Разработка аналитической панели (dashboard).

# %% [markdown]
# ## Шаг 1. Загрузим данные и подготовим их к анализу

# %% [markdown]
# Устанавливаем библиотеки.
# (визуализация пропусков/ загрузка файла из google диска/ чтение xlsx файла/ загрузка файла из yandex диска)

# %%
pip install missingno openpyxl yadisk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 10.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.6/37.6 MB 29.0 MB/s eta 0:00:00:00:0100:01
# ...
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Импортируем библиотеки.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
import missingno as msno
#import gdown
import yadisk

import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# #Загрузка файла с Google Диска
# #Идентификатор файла
# file_id = '12zR3a9L1q60wf-XxZkiXeTOzhXKk9j2C'
#
# #Формирование URL для загрузки
# url = f'https://drive.google.com/uc?id={file_id}'
#
# output = 'payments_2024_01_07.xlsx'
#
# #Загрузка файла
# gdown.download(url, output, quiet=False)
#
# #Чтение Excel-файла
# data = pd.read_excel(output, engine='openpyxl')

# %%
# Загрузка файла с Яндекс Диска
# Инициализация клиента Яндекс.Диска
y = yadisk.YaDisk(token="y0__xD3xZdOGN28NSC62bytEh2K0Kc6OCbUhAkUaX0k7SZUeoNL")

# Путь к файлу на Яндекс.Диске
file_path = "/Аналитика/Мастерская, Простые вещи/payments_2024_01_07.xlsx"

# Локальное имя файла для сохранения
output = "payments_2024_01_07.xlsx"

# Загрузка файла
y.download(file_path, output)

# Чтение Excel-файла
data = pd.read_excel(output, engine='openpyxl')

# %% [markdown]
# Посмотрим на датафрейм, а также на информацию о нём.

# %%
data.sample(5)
# Out:
#       Unnamed: 0          id          action_date      bank              site  \
# 3156         525  2113516664  2024-05-12 11:30:00  Тинькофф  prostieveschi.ru
# 2307          77  2102643506  2024-03-24 01:01:00  Тинькофф  prostieveschi.ru
# 854          854  2118718935  2024-06-10 20:47:00  Тинькофф  prostieveschi.ru
# 15            15  2121983773  2024-06-30 12:52:00  Тинькофф  prostieveschi.ru
# 1949          57  2090121555  2024-02-20 18:32:00  Тинькофф  prostieveschi.ru
#
#       order_id                    customer                         type  \
# 3156       NaN   natalia.lok****@gmail.com            Регулярная оплата
# 2307       NaN  liza.shakhma****@gmail.com            Регулярная оплата
# 854    21747.0       nv.mikh****@yandex.ru  Оплата с созданием подписки
# 15     22704.0        Katerina****@mail.ru                       Оплата
# 1949       NaN            niki****@mail.ru            Регулярная оплата
#
# ...

# %% [markdown]
# Структура data:
# - `Unnamed: 0` — создавшийся автоматически столбец индексов;
# - `id` — идентификатор действия;
# - `action_date` — дата совершения платежа;
# - `bank` — название банка;
# - `site` — сайт перехода;
# - `order_id` — идентификатор платежа;
# - `customer` — почта плательщика;
# - `type` — тип платежа;
# - `operation_sum` — сумма платежа;
# - `operation_currency` — валюта платежа;
# - `commission_sum` — сумма комиссии;
# - `final_sum` — итоговая сумма платежа;
# - `final_currency` — итоговая валюта;
# - `status` — статус платежа;
# - `aim` — цель платежа;
# - `commission_perc` — процент комиссии.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4148 entries, 0 to 4147
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          4148 non-null   int64
#  1   id                  4148 non-null   int64
#  2   action_date         3496 non-null   object
#  3   bank                4148 non-null   object
#  4   site                4148 non-null   object
#  5   order_id            1281 non-null   float64
#  6   customer            4147 non-null   object
#  7   type                4148 non-null   object
#  8   operation_sum       4148 non-null   int64
#  9   operation_currency  4148 non-null   object
#  10  comission_sum       4086 non-null   float64
#  11  final_sum           4086 non-null   float64
#  12  final_currency      4086 non-null   object
#  13  status              4148 non-null   object
#  14  aim                 3475 non-null   object
# ...

# %% [markdown]
# **ВЫВОДЫ:**
#
# Познакомившись с данными мы видим, что в них:
#
# - есть лишний столбец `Unnamed: 0`
# - к сожалению, много пропущенных значений
# - есть столбцы с неверным типом данных
# - названия столбцов корректные
# Размер датасета: 4148 строк.
#
# Из преобразований нужно:
#
# - удалить столбец `Unnamed: 0`, который дублирует значение индексов
# - проанализировать пропуски в столбцах
# - поменять тип данных в столбцах:
#     - `action_date` на datetime;
#     - `order_id` на int.
#
# Затем можно поработать с параметрами детальнее.

# %% [markdown]
# ## Шаг 2. Выполним предобработку данных

# %% [markdown]
# Сначала удалим столбец `Unnamed: 0`.

# %%
del data['Unnamed: 0']
data.sample(5)
# Out:
#               id          action_date      bank              site  order_id  \
# 1157  2117119572  2024-06-01 11:33:00  Тинькофф  prostieveschi.ru       NaN
# 1923  2092097382  2024-02-25 00:19:00  Тинькофф  prostieveschi.ru       NaN
# 3019  2114932914  2024-05-19 17:20:00  Тинькофф  prostieveschi.ru   20952.0
# 401   2120625628  2024-06-22 11:39:00  Тинькофф  prostieveschi.ru   22250.0
# 3706  2124527328  2024-07-15 21:07:00  Тинькофф  prostieveschi.ru       NaN
#
#                      customer               type  operation_sum  \
# 1157  maria.trenina@gmail.com  Регулярная оплата            500
# 1923         yolk****@mail.ru  Регулярная оплата            200
# 3019        Blum-****@mail.ru             Оплата            220
# 401     ahtyamo****@gmail.com             Оплата           1000
# 3706      rozhden****@mail.ru  Регулярная оплата           1000
#
#      operation_currency  comission_sum  final_sum final_currency     status  \
# ...

# %% [markdown]
# ### Изучим уникальные значения и устраним дубликаты

# %% [markdown]
# Проверим датасеты на явные дубликаты.

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Всё отлично, идём дальше. Теперь проверим датасет на неявные дубликаты.

# %% [markdown]
# Из всех данных есть смысл проверять на неявные дубли только столбцы `bank`, `site`, `type`, `operation_currency`, `final_currency`, `status`, `aim`. Посмотрим на уникальные значения в них.

# %%
def print_unique_values(data):
    columns = ['bank', 'site', 'type', 'operation_currency', 'final_currency', 'status', 'aim']
    unique_values = []

    for column in columns:
        if column in data.columns:
            unique_values.append(f"{column}: {data[column].sort_values().unique()}")

    result = "Уникальные значения в столбце:\n" + "\n".join(unique_values)
    print(result)

# вызов функции
print_unique_values(data)
# Out:
# Уникальные значения в столбце:
# bank: ['Тинькофф']
# site: ['prostieveschi.ru']
# type: ['Оплата' 'Оплата с созданием подписки' 'Регулярная оплата']
# operation_currency: ['BYN' 'EUR' 'RUB' 'USD']
# final_currency: ['RUB' nan]
# status: ['Завершена' 'Отклонена']
# aim: ['Вещи с особенностями' 'Поддержите "Простые вещи"'
#  'Пожертвование на ведение уставной деятельности' nan]

# %% [markdown]
# Адрес сайта является единственным источником входа.
# В итоговой сумме платежа и в целях платежа есть пропуски.
#
# В остальном всё корректно и неявных дубликатов не выявлено.

# %% [markdown]
# ### Поработаем с пропущенными значениями

# %% [markdown]
# Выявим пропущенные значения для каждого столбца и посчитаем их.

# %%
print(f'''Количество пропущенных значений: 
{data.isna().sum()}

Процент пропущенных значений: 
{(data.isna().sum() / len(data)).round(4) * 100}''')
# Out:
# Количество пропущенных значений:
# id                       0
# action_date            652
# bank                     0
# site                     0
# order_id              2867
# customer                 1
# type                     0
# operation_sum            0
# operation_currency       0
# comission_sum           62
# final_sum               62
# final_currency          62
# status                   0
# aim                    673
# comission_perc           0
# file                     0
# dtype: int64
#
# Процент пропущенных значений:
# id                     0.00
# action_date           15.72
# bank                   0.00
# site                   0.00
# order_id              69.12
# customer               0.02
# type                   0.00
# operation_sum          0.00
# operation_currency     0.00
# comission_sum          1.49
# final_sum              1.49
# final_currency         1.49
# status                 0.00
# aim                   16.22
# comission_perc         0.00
# ...

# %%
msno.matrix(data, figsize=(8,8), fontsize=10, sparkline=False)

plt.title('Визуализация пропущенных значений', fontsize=14)
plt.show()

# %% [markdown]
# Нужно посмотреть на пропуски детальнее и решить, что с ними делать. 15-70% пропусков — это слишком много. Но как будто в этих пропусках есть системность.
#
# Сначала изучим пропуски в столбце `action_date`.

# %%
temp_tab = data.loc[data['action_date'].isna()].copy()
temp_tab['status'].value_counts()
# Out:
# status
# Отклонена    652
# Name: count, dtype: int64

# %% [markdown]
# В тех строках, где есть пропуски в столбце `action_date`, везде стоит статус 'Отклонена'. Соответственно, если мы удалим эти строки, то они никак не исказят картину последующего анализа. К тому же, без знания даты мы не сможем провести дальнейший анализ. Поэтому удаляем эти пропуски.

# %%
# Предварительно скопируем текущую версию датасета data в full_data, 
# где останутся и завершённые и отклонённые платежи
full_data = data.copy()

# %%
data = data.dropna(subset=['action_date'])

# %%
len(data.loc[data['action_date'].isna()])
# Out:
# 0

# %% [markdown]
# Проверим как поменялась общая картина.

# %%
print(f'''Количество пропущенных значений: 
{data.isna().sum()}

Процент пропущенных значений: 
{(data.isna().sum() / len(data)).round(4) * 100}''')
# Out:
# Количество пропущенных значений:
# id                       0
# action_date              0
# bank                     0
# site                     0
# order_id              2329
# customer                 1
# type                     0
# operation_sum            0
# operation_currency       0
# comission_sum            0
# final_sum                0
# final_currency           0
# status                   0
# aim                    673
# comission_perc           0
# file                     0
# dtype: int64
#
# Процент пропущенных значений:
# id                     0.00
# action_date            0.00
# bank                   0.00
# site                   0.00
# order_id              66.62
# customer               0.03
# type                   0.00
# operation_sum          0.00
# operation_currency     0.00
# comission_sum          0.00
# final_sum              0.00
# final_currency         0.00
# status                 0.00
# aim                   19.25
# comission_perc         0.00
# ...

# %%
msno.matrix(data, figsize=(8,8), fontsize=10, sparkline=False)

plt.title('Визуализация пропущенных значений', fontsize=14)
plt.show()

# %% [markdown]
# Автоматически удалились и пропуски в столбцах `comission_sum`, `final_sum`, `final_currency`.
#
# Посмотрим на единственный пропуск в столбце `customer`.

# %%
data.loc[data['customer'].isna()]
# Out:
#               id          action_date      bank              site  order_id  \
# 2562  2096037273  2024-03-05 13:58:00  Тинькофф  prostieveschi.ru       NaN
#
#      customer               type  operation_sum operation_currency  \
# 2562      NaN  Регулярная оплата            100                RUB
#
#       comission_sum  final_sum final_currency     status  \
# 2562            3.9       96.1            RUB  Завершена
#
#                             aim  comission_perc      file
# 2562  Поддержите "Простые вещи"             3.2  март.xls

# %% [markdown]
# Хоть здесь и есть все остальные важные нам данные, но, к сожалению, не имея возможности идентифицировать жертвователя, мы не сможем использовать эти данные. Удаляем строку.

# %%
data = data.dropna(subset=['customer'])

# %% [markdown]
# Для того чтобы осмысленно заполнить пропуски в целях (`aim`), мы не обладаем необходимой информацией. Поэтому заполним пропущенные значения заглушкой "Неизвестно".

# %%
data['aim'] = data['aim'].fillna(value="Неизвестно")

# %% [markdown]
# Касательно пропусков в столбце `order_id` можно сделать предположение, что там пусто, т.к. платёж не прошёл. Проверим гипотезу.

# %%
temp_tab = data.loc[data['order_id'].isna()].copy()
temp_tab['status'].value_counts()
# Out:
# status
# Завершена    2159
# Отклонена     169
# Name: count, dtype: int64

# %% [markdown]
# Гипотеза не подтвердилась. В таком случае можем просто заменить пустые значения на заглушку 0.

# %%
data['order_id'] = data['order_id'].fillna(value=0)

# обновим индексы
data = data.reset_index(drop=True)

# %% [markdown]
# Посмотрим на результат проделанной работы.

# %%
print(f'''Количество пропущенных значений: 
{data.isna().sum()})

Размер датасета после обработки: 
{data.shape}''')
# Out:
# Количество пропущенных значений:
# id                    0
# action_date           0
# bank                  0
# site                  0
# order_id              0
# customer              0
# type                  0
# operation_sum         0
# operation_currency    0
# comission_sum         0
# final_sum             0
# final_currency        0
# status                0
# aim                   0
# comission_perc        0
# file                  0
# dtype: int64)
#
# Размер датасета после обработки:
# (3495, 16)

# %%
print(f'''Отлично, у нас не осталось пропусков.
В ходе обработки мы потеряли {(round((4148-3495) * 100 / 4148, 2))}% исходных данных.

Можем двигаться дальше.''')
# Out:
# Отлично, у нас не осталось пропусков.
# В ходе обработки мы потеряли 15.74% исходных данных.
#
# Можем двигаться дальше.

# %% [markdown]
# ### Поработаем с типом данных

# %% [markdown]
# Посмотрим ещё раз на типы данных.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3495 entries, 0 to 3494
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  3495 non-null   int64
#  1   action_date         3495 non-null   object
#  2   bank                3495 non-null   object
#  3   site                3495 non-null   object
#  4   order_id            3495 non-null   float64
#  5   customer            3495 non-null   object
#  6   type                3495 non-null   object
#  7   operation_sum       3495 non-null   int64
#  8   operation_currency  3495 non-null   object
#  9   comission_sum       3495 non-null   float64
#  10  final_sum           3495 non-null   float64
#  11  final_currency      3495 non-null   object
#  12  status              3495 non-null   object
#  13  aim                 3495 non-null   object
#  14  comission_perc      3495 non-null   float64
# ...

# %% [markdown]
# Нам нужно:
# - `action_date` привести к формату datetime;
# - `order_id` привести к формату int.

# %% [markdown]
# При приведении к типу datetime выявилась ошибка. У нас есть строки, где значение `action_date` = ' ' *(пробел)*.

# %%
temp_tab = data.loc[data['action_date'] == ' '].copy()
temp_tab.head()
# Out:
#               id action_date      bank              site  order_id  \
# 1557  2080076756              Тинькофф  prostieveschi.ru       0.0
# 1558  2079609225              Тинькофф  prostieveschi.ru       0.0
# 1559  2079397292              Тинькофф  prostieveschi.ru       0.0
# 1560  2079100030              Тинькофф  prostieveschi.ru       0.0
# 1561  2078923096              Тинькофф  prostieveschi.ru       0.0
#
#                           customer               type  operation_sum  \
# 1557   feoktistovaan****@gmail.com  Регулярная оплата            500
# 1558   feoktistovaan****@gmail.com  Регулярная оплата            500
# 1559           polinch****@list.ru  Регулярная оплата            150
# 1560  valeriyavarvar****@gmail.com  Регулярная оплата            500
# 1561           polinch****@list.ru  Регулярная оплата            150
#
#      operation_currency  comission_sum  final_sum final_currency     status  \
# ...

# %% [markdown]
# Проверим с каким они статусом.

# %%
temp_tab['status'].value_counts()
# Out:
# status
# Отклонена    169
# Name: count, dtype: int64

# %% [markdown]
# По факту оказалось, что у нас 169 таких строк и все со статусом 'Отклонена'. Удалим их.

# %%
data = data.loc[data['action_date'] != ' ']

# обновим индексы
data = data.reset_index(drop=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3326 entries, 0 to 3325
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  3326 non-null   int64
#  1   action_date         3326 non-null   object
#  2   bank                3326 non-null   object
#  3   site                3326 non-null   object
#  4   order_id            3326 non-null   float64
#  5   customer            3326 non-null   object
#  6   type                3326 non-null   object
#  7   operation_sum       3326 non-null   int64
#  8   operation_currency  3326 non-null   object
#  9   comission_sum       3326 non-null   float64
#  10  final_sum           3326 non-null   float64
#  11  final_currency      3326 non-null   object
#  12  status              3326 non-null   object
#  13  aim                 3326 non-null   object
#  14  comission_perc      3326 non-null   float64
# ...

# %%
data['action_date'] = pd.to_datetime(data['action_date'], format='%Y-%m-%d %H:%M:%S')
data['order_id'] = data['order_id'].astype('int')

# проверим себя
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3326 entries, 0 to 3325
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  3326 non-null   int64
#  1   action_date         3326 non-null   datetime64[ns]
#  2   bank                3326 non-null   object
#  3   site                3326 non-null   object
#  4   order_id            3326 non-null   int64
#  5   customer            3326 non-null   object
#  6   type                3326 non-null   object
#  7   operation_sum       3326 non-null   int64
#  8   operation_currency  3326 non-null   object
#  9   comission_sum       3326 non-null   float64
#  10  final_sum           3326 non-null   float64
#  11  final_currency      3326 non-null   object
#  12  status              3326 non-null   object
#  13  aim                 3326 non-null   object
#  14  comission_perc      3326 non-null   float64
# ...

# %% [markdown]
# Теперь типы данных корректные.

# %%
print(f'''В ходе обработки мы потеряли ещё данные. Итогово нам пришлось удалить {(round((4148-3326) * 100 / 4148, 2))}% исходных данных.''')
# Out:
# В ходе обработки мы потеряли ещё данные. Итогово нам пришлось удалить 19.82% исходных данных.

# %% [markdown]
# Проведём такую же обработку с датафреймом full_data, в котором остаются записи и по завершённым оплатам, и по отклонённым. Но не будем удалять пропусками в столбцах customer и final_sum, а также не будем ставить заглушку в столбце order_id.

# %%
# удалим строки с пропусками в столбцах customer и final_sum
#full_data = full_data.dropna(subset=['customer'])
#full_data = full_data.dropna(subset=['final_sum'])
# заполним пропуски в столбце order_id заглушкой
#full_data['order_id'] = full_data['order_id'].fillna(value=0)

# заполним пропуски в столбце aim заглушкой
full_data['aim'] = full_data['aim'].fillna(value="Неизвестно")

# заменим пробелы в поле action_date пропусками
full_data.loc[full_data['action_date'] == ' ', 'action_date'] = np.nan

# поменяем тип данных
full_data['action_date'] = pd.to_datetime(full_data['action_date'], format='%Y-%m-%d %H:%M:%S')

# обновим индексы
full_data = full_data.reset_index(drop=True)

full_data['date'] = full_data['action_date'].dt.date
full_data['date'] = pd.to_datetime(full_data['date'])

full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4148 entries, 0 to 4147
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  4148 non-null   int64
#  1   action_date         3327 non-null   datetime64[ns]
#  2   bank                4148 non-null   object
#  3   site                4148 non-null   object
#  4   order_id            1281 non-null   float64
#  5   customer            4147 non-null   object
#  6   type                4148 non-null   object
#  7   operation_sum       4148 non-null   int64
#  8   operation_currency  4148 non-null   object
#  9   comission_sum       4086 non-null   float64
#  10  final_sum           4086 non-null   float64
#  11  final_currency      4086 non-null   object
#  12  status              4148 non-null   object
#  13  aim                 4148 non-null   object
#  14  comission_perc      4148 non-null   float64
# ...

# %% [markdown]
# ### Добавим в таблицу новые столбцы

# %% [markdown]
# Добавим столбец `date` только с датой события и сразу приведём его к типу datetime.

# %%
data['date'] = data['action_date'].dt.date
data['date'] = pd.to_datetime(data['date'])

# %% [markdown]
# ### Выводы

# %% [markdown]
# Предобработка обнаружила пять проблемы в данных:
#
# - пропущенные значения,
# - некорректные типы данных,
# - неуникальные значения.
#
# <b>Датафрейм data</b> - датафрейм, в котором остаются записи только завершённым оплатам.
#
# Мы привели тип данных столбца `action_date` к формату datetime, а столбца `order_id` к формату int.
#
# Пропущенные значения мы заменили/удалили в зависимости от ситуации:
#
# - пропуски и значения ' ' в столбце `action_date` мы удалили, т.к. там везде стоит статус 'Отклонена' и они всё равно непригодны для анализа важных нам показателей.
# - пропуск в столбце `customer` мы также удалили, т.к. без идентификации жертвователя, мы не сможем использовать эти данные.
# - пропуски в столбце `aim` заменили на заглушку "Неизвестно".
# - пропуски в столбце `order_id` заменили на заглушку 0.
#
# Неуникальные значения столбцов привели в порядок.
#
# Также мы добавили в датасет новый столбец:
# - `date`, в котором хранится дата совершения платежа без времени.
#
# В ходе обработки мы потеряли всего 19.82% исходных данных.
#
# <b>Датафрейм full_data</b> - датафрейм, в котором остаются записи и по завершённым оплатам, и по отклонённым.
#
# Проведём схожую обработку за ичключением, что не стали удалять пропуски в столбцах customer и final_sum, а также не стали ставить заглушку в столбце order_id. Ячейки с пробелами в столбце action_date заменили Nan.
#
# Теперь можно перейти к анализу данных.

# %% [markdown]
# ## Шаг 3. Анализ данных

# %% [markdown]
# Проверим, что в датасете `data` остались данные только со статусом "Завершена".

# %%
data['status'].value_counts()
# Out:
# status
# Завершена    3326
# Name: count, dtype: int64

# %% [markdown]
# Отлично, можно переходить к RFM-анализу.

# %% [markdown]
# ### RFM-анализ

# %% [markdown]
# Посчитаем общую сумму пожертвований по жертвователю, дату последнего пожертвования и количество успешных пожертвований.

# %%
rfm_tab = data.groupby('customer', as_index=False).agg({'final_sum':'sum', 'action_date':['min','max'], 'order_id':'count'})
rfm_tab.columns = rfm_tab.columns.droplevel()
rfm_tab = rfm_tab.reset_index(drop=True)
cols = ['customer', 'total_final_sum', 'first_ts', 'last_ts', 'cnt_order_id']
rfm_tab.columns = cols
rfm_tab
# Out:
#                         customer  total_final_sum            first_ts  \
# 0                     ****@bk.ru           968.00 2024-06-13 18:33:00
# 1                     ****@de.ru           968.00 2024-07-04 16:36:00
# 2                    ****@eml.cc          1452.00 2024-06-17 14:33:00
# 3                 ****@gksnab.ru          2420.00 2024-05-07 22:50:00
# 4                 ****@gmail.com            96.10 2024-06-15 01:47:00
# ...                          ...              ...                 ...
# 1471  zotova.liuda****@yandex.ru           968.00 2024-06-26 11:51:00
# 1472          zvon****@gmail.com           322.34 2024-06-24 01:38:00
# 1473           zxc****@yandex.ru           484.00 2024-07-03 13:02:00
# 1474           zxc2081@yandex.ru          7260.00 2024-06-03 13:00:00
# 1475            zzzz****@mail.ru           288.30 2024-05-27 22:29:00
#
#                  last_ts  cnt_order_id
# 0    2024-06-13 18:33:00             1
# 1    2024-07-04 16:36:00             1
# ...

# %%
rfm_tab.describe()
# Out:
#        total_final_sum                       first_ts  \
# count      1476.000000                           1476
# mean       1665.522832  2024-05-12 21:56:30.772357888
# min           6.100000            2024-01-01 09:55:00
# 25%         387.200000            2024-05-12 12:03:00
# 50%         672.700000            2024-06-03 17:40:30
# 75%        1379.400000            2024-06-22 11:14:15
# max      145200.000000            2024-07-31 21:34:00
# std        5376.766771                            NaN
#
#                              last_ts  cnt_order_id
# count                           1476   1476.000000
# mean   2024-06-20 05:57:15.934959360      2.253388
# min              2024-01-11 09:12:00      1.000000
# 25%              2024-06-03 14:06:15      1.000000
# 50%              2024-06-22 18:26:30      1.000000
# 75%              2024-07-13 01:10:00      2.000000
# max              2024-07-31 21:34:00     20.000000
# std                              NaN      2.222113

# %% [markdown]
# В глаза сразу бросается максимальное суммарное пожертвование в размере 145200. Оно в несколько крат превышает медиану и среднее.

# %% [markdown]
# ##### Recency

# %% [markdown]
# Посчитаем количество дней с последнего пожертвования.

# %%
maxx_date = (max(rfm_tab['last_ts'])) + timedelta(days=1)

rfm_tab['days_since_last_donation'] = rfm_tab['last_ts'].apply(lambda x: maxx_date - x)
rfm_tab['days_since_last_donation'] = rfm_tab['days_since_last_donation'].dt.days.astype('int16')
rfm_tab.sample(5)
# Out:
#                      customer  total_final_sum            first_ts  \
# 29        4contac****@mail.ru            580.8 2024-05-27 14:00:00
# 1038            n****@mail.ru           1258.4 2024-03-21 19:09:00
# 264        Svetmi****@mail.ru            387.2 2024-06-14 21:04:00
# 545     defback****@gmail.com            968.0 2024-06-28 22:49:00
# 447   arina.mik****@gmail.com            484.0 2024-05-31 15:08:00
#
#                  last_ts  cnt_order_id  days_since_last_donation
# 29   2024-05-27 14:00:00             1                        66
# 1038 2024-05-29 14:56:00             2                        64
# 264  2024-07-14 21:05:00             2                        18
# 545  2024-06-28 22:49:00             1                        33
# 447  2024-05-31 15:08:00             1                        62

# %% [markdown]
# Посмотрим на распределение Recency.

# %%
plt.figure(figsize=(10, 4))
ax = sns.histplot(x = 'days_since_last_donation', kde=True, data = rfm_tab, alpha=.3, binwidth=2)

ax.set_title('График распределения количества дней с последнего пожертвования')
ax.set_xlabel('Дней с последнего пожертвования')
plt.xticks(range(0, 203, 10))
plt.show()

rfm_tab['days_since_last_donation'].describe()
# Out:
# count    1476.000000
# mean       42.250678
# std        32.297591
# min         1.000000
# 25%        19.000000
# 50%        40.000000
# 75%        59.000000
# max       203.000000
# Name: days_since_last_donation, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# Интересно что за пик пожертвования был за 40 дней до даты отсчёта. Возможно какая-то маркетинговая компания/ реклама.
#
# Исследование каналов «Простых вещей» показало, что в этот день была встреча с основательницей «Простых вещей» Машей Грековой в Москве. Возможно это как-то побудило направить в фонд деньги.
#
#  </div>

# %%
temp_tab_40 = rfm_tab.loc[rfm_tab['days_since_last_donation'] == 40].copy()
temp_tab_40
# Out:
#                      customer  total_final_sum            first_ts  \
# 12          123****@gmail.com             96.1 2024-06-22 10:32:00
# 17             21****@mail.ru             96.1 2024-06-22 10:48:00
# 19            268****@mail.ru            968.0 2024-06-22 14:48:00
# 21             31****@mail.ru            968.0 2024-06-22 11:01:00
# 31              7****@mail.ru            968.0 2024-06-22 15:52:00
# ...                       ...              ...                 ...
# 1408  vik.mahan****@yandex.ru            193.6 2024-06-22 12:02:00
# 1426    vstroykas****@mail.ru            484.0 2024-06-22 18:29:00
# 1442    yana_ganc****@mail.ru            484.0 2024-06-22 17:27:00
# 1454      yulka****@gmail.com            193.6 2024-06-22 15:03:00
# 1457     zalina****@gmail.com            242.0 2024-06-22 11:23:00
#
#                  last_ts  cnt_order_id  days_since_last_donation
# 12   2024-06-22 10:32:00             1                        40
# ...

# %% [markdown]
# В этот день было совершено 125 пожертвований/ покупок!

# %%
plt.figure(figsize=(7, 3))
ax = sns.boxplot(x = 'days_since_last_donation', data = rfm_tab)

ax.set_title('Диаграмма размаха количества дней с последнего пожертвования')
ax.set_xlabel('Дней с последнего пожертвования')

plt.show()

# %% [markdown]
# Разобьём **Recency** следующим образом:
# - **3**, 0-30: те, кто жертвуют раз в месяц по ежемесячной подписке и те, кто в целом жертвовал недавно.
# - **2**, 30-90: относительно недавние пожертвования, 1-3 месяца.
# - **1**, 90+: давние пожертвования.

# %%
def recency_score(recency):
    if recency <= 30:
        return 3
    elif recency <= 90:
        return 2
    else:
        return 1
    
rfm_tab['recency'] = rfm_tab['days_since_last_donation'].apply(recency_score)

# %% [markdown]
# Посмотрим какие у нас сформировались группы по Recency.

# %%
plt.figure(figsize=(4, 4))
ax = sns.countplot(x = 'recency', data = rfm_tab)

ax.set_title('График распределения Recency')
ax.set_xlabel('Recency')
plt.yticks(range(0, 850, 100))

for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='bottom')

plt.show()

# %% [markdown]
# ##### Frequency

# %% [markdown]
# Посмотрим на распределение Frequency.

# %%
plt.figure(figsize=(10, 4))
ax = sns.histplot(x = 'cnt_order_id', kde=True, data = rfm_tab, alpha=.3, binwidth=1)

ax.set_title('График распределения количества пожертвований')
ax.set_xlabel('Количество пожертвований')
plt.xticks(range(0, 21, 1))
plt.show()

rfm_tab['cnt_order_id'].describe()
# Out:
# count    1476.000000
# mean        2.253388
# std         2.222113
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max        20.000000
# Name: cnt_order_id, dtype: float64

# %%
plt.figure(figsize=(7, 3))
ax = sns.boxplot(x = 'cnt_order_id', data = rfm_tab)

ax.set_title('Диаграмма размаха количества пожертвований')
ax.set_xlabel('Количество пожертвований')

plt.xlim(0, 21)
plt.xticks(range(0, 21, 1))

plt.show()

# %% [markdown]
# Разобьём **Frequency** следующим образом:
# - **1**, 0-3: жертвовали редко.
# - **2**, 3-8: жертвовали несколько раз.
# - **3**, 8+: много пожертвований.

# %%
def frequency_score(frequency):
    if frequency <= 3:
        return 1
    elif frequency <= 8:
        return 2
    else:
        return 3
    
rfm_tab['frequency'] = rfm_tab['cnt_order_id'].apply(frequency_score)

# %% [markdown]
# Посмотрим какие у нас сформировались группы по Frequency.

# %%
plt.figure(figsize=(4, 4))
ax = sns.countplot(x = 'frequency', data = rfm_tab)

ax.set_title('График распределения Frequency')
ax.set_xlabel('Frequency')
plt.yticks(range(0, 1350, 100))

for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='bottom')

plt.show()

# %% [markdown]
# ##### Monetary

# %% [markdown]
# Посмотрим на распределение Monetary.

# %%
plt.figure(figsize=(10, 4))
ax = sns.histplot(x = 'total_final_sum', kde=True, data = rfm_tab, alpha=.3)

ax.set_title('График распределения сумм пожертвований')
ax.set_xlabel('Сумма пожертвования')
plt.show()

rfm_tab['total_final_sum'].describe()
# Out:
# count      1476.000000
# mean       1665.522832
# std        5376.766771
# min           6.100000
# 25%         387.200000
# 50%         672.700000
# 75%        1379.400000
# max      145200.000000
# Name: total_final_sum, dtype: float64

# %% [markdown]
# Посмотрим на выбросы с помощью ящика с усами.

# %%
plt.figure(figsize=(7, 3))
ax = sns.boxplot(x = 'total_final_sum', data = rfm_tab)

ax.set_title('Диаграмма размаха сумм пожертвований (детальнее)')
ax.set_xlabel('Сумма пожертвования')

plt.show()

# %% [markdown]
# У нас есть два выброса после 60 тыс., которые очень сильно перетягивают выборку. Хотелось бы их удалить, но эти жертвователи важны в финальной выборке для планирования взаимодействия с ними.

# %% [markdown]
# Укрупним график распределения для большей наглядности.

# %%
plt.figure(figsize=(10, 4))
ax = sns.histplot(x = 'total_final_sum', kde=True, data = rfm_tab, alpha=.3)

ax.set_title('График распределения сумм пожертвований (детальнее)')
ax.set_xlabel('Сумма пожертвования')
plt.xlim(0, 8000)
plt.xticks(range(0, 8500, 500))
plt.show()

rfm_tab['total_final_sum'].describe()
# Out:
# count      1476.000000
# mean       1665.522832
# std        5376.766771
# min           6.100000
# 25%         387.200000
# 50%         672.700000
# 75%        1379.400000
# max      145200.000000
# Name: total_final_sum, dtype: float64

# %% [markdown]
# Разобьём **Monetary** следующим образом:
# - **1**, 0-500: маленькая сумма пожертвований.
# - **2**, 500-3000: небольшая/ средняя сумма пожертвований.
# - **3**, 3000+: большая сумма пожертвований.

# %%
def monetary_score(monetary):
    if monetary <= 500:
        return 1
    elif monetary <= 3000:
        return 2
    else:
        return 3
    
rfm_tab['monetary'] = rfm_tab['total_final_sum'].apply(monetary_score)

# %% [markdown]
# Посмотрим какие у нас сформировались группы по Monetary.

# %%
plt.figure(figsize=(4, 4))
ax = sns.countplot(x = 'monetary', data = rfm_tab)

ax.set_title('График распределения Monetary')
ax.set_xlabel('Monetary')
plt.yticks(range(0, 900, 100))

for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='bottom')

plt.show()

# %% [markdown]
# #### Сводная таблица по сегментам

# %%
rfm_tab['rfm'] = rfm_tab['recency'].astype('str') + rfm_tab['frequency'].astype('str') + rfm_tab['monetary'].astype('str')

# %%
#rfm_tab['start_date_f'] = data.groupby('customer')['action_date'].transform('min')
#rfm_tab['end_date_f'] = data.groupby('customer')['action_date'].transform('max')

#rfm_tab = pd.merge(rfm_tab, start_date_f, left_on='customer', right_index=True)
#rfm_tab = pd.merge(rfm_tab, end_date_f, left_on='customer', right_index=True)
rfm_tab['lifetime'] = (rfm_tab['last_ts'] - rfm_tab['first_ts'] + timedelta(days=1)).dt.days
rfm_tab.sample(5)
# Out:
#                           customer  total_final_sum            first_ts  \
# 298           Wolf.d****@gmail.com            580.8 2024-06-12 19:48:00
# 184   Maria.shchennikova@gmail.com            968.0 2024-06-08 10:04:00
# 531           darial****@yandex.ru            968.0 2024-06-11 09:53:00
# 1373            usol****@gmail.com           5808.0 2024-05-30 09:53:00
# 223        Olilymota****@gmail.com            968.0 2024-06-10 14:58:00
#
#                  last_ts  cnt_order_id  days_since_last_donation  recency  \
# 298  2024-07-12 19:48:00             2                        20        3
# 184  2024-06-08 10:04:00             1                        54        2
# 531  2024-07-11 09:53:00             2                        21        3
# 1373 2024-07-30 09:53:00             3                         2        3
# 223  2024-06-10 14:58:00             1                        52        2
#
#       frequency  monetary  rfm  lifetime
# 298           1         2  312        31
# ...

# %% [markdown]
# **Recency**:
# - **1**, 90+: давние пожертвования.
# - **2**, 30-90: относительно недавние пожертвования, 1-3 месяца.
# - **3**, 0-30: те, кто жертвовал недавно, 1 месяц (также могут быть те, кто жертвуют раз в месяц по ежемесячной подписке).
#
# **Frequency**:
# - **1**, 0-3: жертвовали редко.
# - **2**, 3-8: жертвовали несколько раз.
# - **3**, 8+: много пожертвований.
#
# **Monetary**:
# - **1**, 0-500: маленькая сумма пожертвований.
# - **2**, 500-3000: небольшая/ средняя сумма пожертвований.
# - **3**, 3000+: большая сумма пожертвований.

# %%
plt.figure(figsize=(15,5))

order = rfm_tab['rfm'].value_counts().index
# order = rfm_tab['rfm'].sort_values().unique() - лексикографический порядок
ax = sns.countplot(x = 'rfm', data = rfm_tab, order = order)

ax.set_title('График распределения RFM по количеству человек')
ax.set_xlabel('RFM')

for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='bottom')

plt.show()

# %%
rfm__total_tab = rfm_tab.pivot_table(index='rfm', values={'customer', 'lifetime', 'total_final_sum'}, aggfunc={'customer':'nunique', 'lifetime':'mean', 'total_final_sum':['mean','sum']}).round(2)
rfm__total_tab.columns = rfm__total_tab.columns.droplevel()
rfm__total_tab = rfm__total_tab.reset_index()
new_cols = ['RFM', 'Кол-во жертвователей', 'Lifetime', 'Среднее пожертвование, руб', 'Общая сумма пожертвований, руб']
rfm__total_tab.columns = new_cols
rfm__total_tab
# Out:
#     RFM  Кол-во жертвователей  Lifetime  Среднее пожертвование, руб  \
# 0   111                    53      5.04                      327.47
# 1   112                    27     27.19                     1158.01
# 2   113                     6      1.00                    30371.00
# 3   121                     1     92.00                      384.40
# 4   122                     2    107.00                     1790.80
# 5   123                     1     92.00                     3872.00
# 6   211                   440      1.51                      340.21
# 7   212                   272      5.13                     1160.89
# 8   213                    36      6.39                     9479.41
# 9   221                     3    140.67                      448.93
# 10  222                    14    156.50                     1406.09
# 11  223                     6    139.33                     8300.60
# 12  233                     2     67.00                     5227.20
# ...

# %% [markdown]
# Топ-10 категорий по суммам пожертвований.

# %%
rfm_tab.groupby('rfm')['total_final_sum'].sum().sort_values(ascending=False).nlargest(10)
# Out:
# rfm
# 323    591244.72
# 213    341258.72
# 212    315762.14
# 312    285382.42
# 322    195439.60
# 113    182226.00
# 211    149693.37
# 313    106964.00
# 333     95658.99
# 223     49803.60
# Name: total_final_sum, dtype: float64

# %% [markdown]
# Топ-10 жертвователей, внёсших самые больше суммы.

# %%
rfm_tab.groupby('customer')['total_final_sum'].sum().sort_values(ascending=False).nlargest(10)
# Out:
# customer
# humblehelptope****@gmail.com    145200.00
# Bar-m****@yandex.ru              77440.00
# n-sorokina@yandex.ru             49368.00
# azat.khali****@gmail.com         48400.00
# avito****@hotmail.com            38720.00
# jevge****@bk.ru                  33880.00
# ket****@mail.ru                  33880.00
# holo****@gmail.com               28739.92
# hel****@mail.ru                  25168.00
# art.ma****@gmail.com             23716.00
# Name: total_final_sum, dtype: float64

# %%
rfm_tab.loc[rfm_tab['customer'] == 'humblehelptope****@gmail.com']
# Out:
#                          customer  total_final_sum            first_ts  \
# 703  humblehelptope****@gmail.com         145200.0 2024-03-19 11:20:00
#
#                 last_ts  cnt_order_id  days_since_last_donation  recency  \
# 703 2024-03-19 20:53:00             3                       135        1
#
#      frequency  monetary  rfm  lifetime
# 703          1         3  113         1

# %% [markdown]
# Топ-10 категорий по количеству жертвователей.

# %%
rfm_tab.groupby('rfm')['customer'].nunique().sort_values(ascending=False).nlargest(10)
# Out:
# rfm
# 211    440
# 212    272
# 312    223
# 311    152
# 322    126
# 323     77
# 111     53
# 213     36
# 112     27
# 222     14
# Name: customer, dtype: int64

# %% [markdown]
# #### Выводы
#
# <div class="alert alert-block alert-success">
#
# Наибольшую часть пожертвований приносят следующие группы:
# - 323: 591244.72 руб.
# - 213: 341258.72 руб.
# - 212: 315762.14 руб.
# - 312: 285382.42 руб.
# - 322: 195439.60 руб.
#
# Группа жертвующая небольшие суммы, но тем не менее наиболее многочисленная. Поэтому очень важная.
# - 211: 149693.37 руб.
#
# Группа людей, которые жертвовали давно, редко, но большие суммы. Можно как-то их "разбудить".
# - 113: 182226.00 руб.
#
# А непосредственно человека с e-mail: humblehelptope****@gmail.com. Он пожертвовал 145200.00 руб.
# </div>

# %% [markdown]
# ### Когортный анализ

# %% [markdown]
# Посмотрим данными за какой период мы располагаем. Найдём дату первого и последнего события.

# %%
min_date = data['date'].dt.date.min()
max_date = data['date'].dt.date.max()

print(f'''Дата первого события: {min_date}
Дата последнего события: {max_date}
Количество дней от первого события до последнего: {(max_date - min_date).days}''')
# Out:
# Дата первого события: 2024-01-01
# Дата последнего события: 2024-07-31
# Количество дней от первого события до последнего: 212

# %% [markdown]
# Всего лог включает данные за 7 месяцев — это наши 7 когорт.

# %% [markdown]
# Напишем функцию для создания пользовательских профилей с датой первого пожертвования и вызовем её.

# %%
def get_profiles(data):

    # сортируем сессии по почте пользователя и дате пожертвования
    # группируем по почте и находим первые значения action_date
    # столбец с временем первого пожертвования назовём first_ts
    # от англ. first timestamp -- первая временная отметка
    profiles = (
        data.sort_values(by=['customer', 'action_date'])
        .groupby('customer')
        .agg({'action_date':['first', 'last'], 'type': 'first', 'aim': 'first'})
    )

    profiles.columns = profiles.columns.droplevel()
    profiles = profiles.reset_index()
    new_cols = ['customer', 'first_ts', 'last_ts', 'type', 'aim']
    profiles.columns = new_cols

    # определяем дату первого пожертвования
    # и первый день месяца, в который это пожертвование произошло
    # эти данные понадобятся для когортного анализа
    profiles['first_dt'] = profiles['first_ts'].dt.date
    #profiles['first_month'] = profiles['first_ts'].astype('datetime64[ns]').dt.month
    profiles['first_month'] = profiles['first_ts'].dt.to_period("M")#.astype('datetime64[ns]')
    
    return profiles

# %%
profiles = get_profiles(data)
profiles.sample(5)
# Out:
#                                 customer            first_ts  \
# 1143                olyar****@rambler.ru 2024-01-11 14:53:00
# 754                julia.nikit@gmail.com 2024-06-04 21:32:00
# 1063  nastya.abramova.0378****@gmail.com 2024-06-15 20:38:00
# 1327                  t_raza****@mail.ru 2024-06-26 19:49:00
# 1440              yana-demid****@mail.ru 2024-01-27 23:46:00
#
#                  last_ts                         type  \
# 1143 2024-07-11 14:53:00            Регулярная оплата
# 754  2024-06-04 21:32:00            Регулярная оплата
# 1063 2024-07-15 20:39:00  Оплата с созданием подписки
# 1327 2024-07-26 19:50:00  Оплата с созданием подписки
# 1440 2024-07-28 23:47:00            Регулярная оплата
#
#                             aim    first_dt first_month
# 1143                 Неизвестно  2024-01-11     2024-01
# 754   Поддержите "Простые вещи"  2024-06-04     2024-06
# 1063  Поддержите "Простые вещи"  2024-06-15     2024-06
# ...

# %%
profiles.pivot_table(
    index='first_dt',  # даты первых посещений
    columns='aim',  # источник переходов
    values='customer',  # почты пользователей
    aggfunc='nunique'  # подсчёт уникальных значений
).plot(figsize=(15, 5), grid=True)

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Вывод</b>
#
# Был небольшой приток жертвователей с января по февраль. Потом новые жертвователи появлялись крайне редко и такая картина сохраналась до конца мая.\
# С конца мая до почти середины июля был небывалый приток жертвователей.
#
# </div>

# %%
profiles.pivot_table(
    index='first_dt',  # даты первых посещений
    columns='type',  # источник переходов
    values='customer',  # почты пользователей
    aggfunc='nunique'  # подсчёт уникальных значений
).plot(figsize=(15, 5), grid=True)

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Вывод:</b>
#
# Снова видим уже отмеченный ранее пик в районе 22 июня. Похоже либо кто-то просто вдохновился выступлением Машей Грековой (основательницы «Простых вещей») в Москве, либо там был ещё и маркет с продажей продукции фонда.
# </div>

# %% [markdown]
# #### Retention Rate

# %% [markdown]
# Создадим табличку `result_raw` для подсчёта Retention Rate.

# %%
def get_retention(profiles):

    # собираем «сырые» данные для расчёта удержания
    result_raw = profiles[['customer', 'first_ts', 'last_ts', 'first_dt', 'first_month']].copy()
    # устарело #result_raw['lifetime_months'] = ((result_raw['last_ts'] - result_raw['first_ts'] + timedelta(days=1)) / np.timedelta64(1, 'M')).round().astype('int')
    #result_raw['lifetime_days'] = (result_raw['last_ts'] - result_raw['first_ts'] + timedelta(days=1)).dt.days
    # Вычисляем разницу в днях
    delta_days = (result_raw['last_ts'] - result_raw['first_ts'] + timedelta(days=1)) / np.timedelta64(1, 'D')
    # Преобразуем дни в месяцы, используя среднее количество дней в месяце (30.44)
    result_raw['lifetime_months'] = (delta_days / 30.44).round().astype('int')

    # рассчитываем удержание
    result_grouped = result_raw.pivot_table(index=['first_month'], columns='lifetime_months', values='customer', aggfunc='nunique')
    
    cohort_sizes = (
        result_raw.groupby('first_month')
        .agg({'customer': 'nunique'})
        .rename(columns={'customer': 'cohort_size'})
    )
    
    result_grouped = cohort_sizes.merge(
        result_grouped, on='first_month', how='left').fillna(0)
    
    result_grouped = result_grouped.div(result_grouped['cohort_size'], axis=0)

    # восстанавливаем столбец с размерами когорт
    result_grouped['cohort_size'] = cohort_sizes

    # возвращаем таблицу удержания и сырые данные
    # сырые данные пригодятся, если нужно будет отыскать ошибку в расчётах
    return result_raw, result_grouped

# %%
retention_raw, retention = get_retention(profiles)

retention
# Out:
#              cohort_size         0         1         2         3         4  \
# first_month
# 2024-01              251  0.043825  0.015936  0.035857  0.019920  0.019920
# 2024-02               12  0.166667  0.083333  0.000000  0.166667  0.000000
# 2024-03               52  0.596154  0.019231  0.115385  0.096154  0.153846
# 2024-04               42  0.595238  0.047619  0.142857  0.190476  0.023810
# 2024-05              275  0.621818  0.029091  0.349091  0.000000  0.000000
# 2024-06              698  0.772206  0.227794  0.000000  0.000000  0.000000
# 2024-07              146  1.000000  0.000000  0.000000  0.000000  0.000000
#
#                     5         6        7
# first_month
# 2024-01      0.047809  0.796813  0.01992
# 2024-02      0.583333  0.000000  0.00000
# 2024-03      0.019231  0.000000  0.00000
# 2024-04      0.000000  0.000000  0.00000
# 2024-05      0.000000  0.000000  0.00000
# 2024-06      0.000000  0.000000  0.00000
# 2024-07      0.000000  0.000000  0.00000

# %%
plt.figure(figsize=(10, 10))

# строим тепловую карту удержания

sns.heatmap(
    retention.drop(columns=['cohort_size']),
    annot=True,
    fmt='.2%',
    ax=plt.subplot(2, 1, 1)
)
plt.title('Тепловая карта удержания')
plt.xlabel('Лайфтайм (месяц)')
plt.ylabel('Когорта')
plt.yticks(rotation=0)

# строим кривые удержания

report = retention.drop(columns = ['cohort_size']).T
report = retention.drop(columns = ['cohort_size', 0])

report.T.plot(
    grid=True,
    xticks=list(report.columns.values), 
    ax=plt.subplot(2, 1, 2)
)
plt.xlabel('Лайфтайм (месяц)')
plt.title('Кривые удержания по месяцам привлечения')

plt.xticks(range(0, 7, 1))

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Выводы:</b>
#
# Кривые удержания вторят хитмэпу: удержание крайне нестабильное.
#
# 1. Сильное удержание клиентов:
#    - В течение первых двух месяцев для некоторых когорты (например, для января 2024 года) retention rate остается относительно высоким, что может свидетельствовать о хорошем уровне вовлеченности клиентов. Особенно это заметно, где retention rate достигает 80% на 6-й месяц (для января).
#
# 2. Различия между когортами:
#    - Когорты имеют значительные различия в retention rate. Например, клиенты, пришедшие в мае 2024 года, показали высокие результаты на первом месяце (62.18%) и отличные следующие месяцы, в то время как когорты февраля показывают значительно более низкие показатели.
#
# 3. Проблемы с удержанием:
#    - Для некоторых когорт, как, например, за февраль 2024 года, наблюдается значительное уменьшение retention rate после первого месяца, что может свидетельствовать о проблемах в обеспечении дальнейшего вовлечения клиентов.
#
# 4. Снижение retention rate:
#    - Наблюдается явная тенденция к снижению retention rate по мере увеличения числа месяцев, что может указывать на необходимость улучшения стратегии удержания клиентов или анализа причин ухода пользователей.
#
# 5. Выделение успешных когорт:
#    - Когорты, такие как июнь 2024 года, показывают высокий уровень retention, что также стоит проанализировать в положительном контексте. Следует выяснить, какие факторы способствовали высокому удержанию в этом месяце.
#
# </div>

# %% [markdown]
# #### ARPU (средний чек)

# %%
result_raw = profiles.copy()

result_raw = result_raw.merge(
        # добавляем в профили время совершения покупок и выручку
        data[['customer', 'action_date', 'final_sum']],
        on='customer',
        how='left',
    )

cohort_sizes = (
        result_raw.groupby('first_month')
        .agg({'customer': 'nunique', 'final_sum':'sum'})
        .rename(columns={'customer': 'cohort_size'})
)

cohort_sizes['ARPU'] = cohort_sizes['final_sum'] / cohort_sizes['cohort_size']

cohort_sizes
# Out:
#              cohort_size  final_sum         ARPU
# first_month
# 2024-01              251  820108.79  3267.365697
# 2024-02               12   24390.80  2032.566667
# 2024-03               52  250551.50  4818.298077
# 2024-04               42  149943.56  3570.084762
# 2024-05              275  311072.87  1131.174073
# 2024-06              698  735580.56  1053.840344
# 2024-07              146  166663.62  1141.531644

# %%
# строим тепловую карту ARPU

plt.figure(figsize=(11, 5))

sns.heatmap(cohort_sizes.drop(columns=['cohort_size', 'final_sum']), 
            annot=True, 
            fmt='.2f',
            ax=plt.subplot(1, 2, 1))
plt.title('Тепловая карта ARPU (среднего чека)')
plt.ylabel('Когорта, мес')
plt.xlabel('Средний чек, руб.')

# строим тепловую карту кол-ва человек в когорте

sns.heatmap(cohort_sizes.drop(columns=['ARPU', 'final_sum']), 
            annot=True, 
            fmt='.2f',
            ax=plt.subplot(1, 2, 2))
plt.title('Тепловая карта кол-ва пользователей в когорте')
plt.ylabel('')
plt.xlabel('Количество человек')

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Выводы:</b>
#
# Средний чек снижается и следовательно нужно привлекать больше жертвователей. Но важно отметить, что по сравнению с февралём, мартом и апрелем, количество жертвователей сильно возрасло в мае, июне, июле, но при этом их пожертвования/покупки стали меньше.
# </div>

# %% [markdown]
# #### LTV

# %%
def get_ltv(
    profiles,  # Шаг 1. получаем профили и данные о покупках
    purchases, # это data
    dimensions=[],
):

    # Шаг 2. добавляем данные о покупках в профили
    
    result_raw = profiles.copy()
    result_raw = result_raw.merge(
        # добавляем в профили время совершения покупок и выручку
        purchases[['customer', 'action_date', 'final_sum']],
        on='customer',
        how='left',
    )

    # Шаг 3. рассчитываем лайфтайм пользователя для каждой покупки
    # Вычисляем разницу в днях
    delta_days = (result_raw['last_ts'] - result_raw['first_ts'] + timedelta(days=1)) / np.timedelta64(1, 'D')
    # Преобразуем дни в месяцы, используя среднее количество дней в месяце (30.44)
    result_raw['lifetime_months'] = (delta_days / 30.44).round().astype('int')
    
    result_raw['lifetime_days'] = (
        result_raw['last_ts'] - result_raw['first_ts'] + timedelta(days=1)
    ).dt.days
    
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All donors'
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims):

        # Шаг 4. строим таблицу выручки
        result = df.pivot_table(
            index=dims,
            columns='lifetime_months',
            values='final_sum',  # в ячейках -- выручка за каждый лайфтайм
            aggfunc='sum',
        )

        # Шаг 5. считаем сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)

        # Шаг 6. вычисляем размеры когорт
        cohort_sizes = (
            result_raw.groupby(dims)
            .agg({'customer': 'nunique'})
            .rename(columns={'customer': 'cohort_size'})
        )

        # Шаг 7. объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)

        # Шаг 8. считаем LTV
        # делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу LTV
    result_grouped = group_by_dimensions(result_raw, dimensions)

    # для таблицы динамики LTV убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []
    # получаем таблицу динамики LTV
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['first_month']
    )

    # возвращаем обе таблицы LTV и сырые данные
    return result_raw, result_grouped, result_in_time

# %%
ltv_raw, ltv, ltv_history = get_ltv(profiles, data)

plt.figure(figsize=(10, 10))

# строим тепловую карту LTV

sns.heatmap(ltv.drop(columns=['cohort_size']), 
            annot=True, 
            fmt='.2f',
            ax=plt.subplot(2, 1, 1))
plt.title('Тепловая карта LTV без разбивки')
plt.xlabel('Лайфтайм (месяц)')

# строим кривую LTV без разбивки

ltv_raw, ltv, ltv_history = get_ltv(profiles, data)
report = ltv.drop(columns=['cohort_size'])

plt.figure(figsize=(10, 5))

report.T.plot(grid=True, 
              xticks=list(report.columns.values), 
              ax=plt.subplot(2, 1, 2))
plt.title('Кривая LTV без разбивки')
plt.ylabel('LTV, руб')
plt.xlabel('Лайфтайм (месяц)')

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Выводы:</b>
#
# Итоговая сумма в данных о пожертвованиях указана в рублях. Месячный LTV жертвователей, совершивших первое пожартвование/ покупку в июле, составили 1665 рублей.
# </div>

# %%
# строим кривую LTV по типу пожертвования

ltv_raw, ltv, ltv_history = get_ltv(profiles, data, dimensions=['type'])
report = ltv.drop(columns=['cohort_size'])

plt.figure(figsize=(10, 5))

report.T.plot(grid=True, 
              xticks=list(report.columns.values))
plt.title('Кривая LTV с разбивкой по типу пожертвования')
plt.ylabel('LTV, руб')
plt.xlabel('Лайфтайм')

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Выводы:</b>
#
# Мы видим как активно растёт LTV оплаты с созданием подписки, уходя на плато в районе 1100 руб и через 3 месяца закономерно кратно увеличивается регулярная оплата, возрастая за 1 месяц от 500 до 2100 руб.
# </div>

# %% [markdown]
# ### Маркетинговый анализ

# %% [markdown]
# #### Маркетинговые показатели:

# %%
#data['first_year'] = data['date'].dt.year
data['first_month'] = data['date'].dt.month
data['first_week'] = data['date'].dt.isocalendar().week
data['first_date'] = data['date'].dt.date

data.sample(3)
# Out:
#               id         action_date      bank              site  order_id  \
# 1354  2075760384 2024-01-21 21:06:00  Тинькофф  prostieveschi.ru         0
# 2687  2126903072 2024-07-30 09:46:00  Тинькофф  prostieveschi.ru         0
# 2929  2124880707 2024-07-18 05:43:00  Тинькофф  prostieveschi.ru         0
#
#                   customer               type  operation_sum  \
# 1354   ctpel****@gmail.com  Регулярная оплата           1000
# 2687  asmine****@gmail.com  Регулярная оплата            400
# 2929    ramens****@mail.ru  Регулярная оплата            500
#
#      operation_currency  comission_sum  final_sum final_currency     status  \
# 1354                RUB           32.0      968.0            RUB  Завершена
# 2687                RUB           12.8      387.2            RUB  Завершена
# 2929                RUB           16.0      484.0            RUB  Завершена
#
#                             aim  comission_perc        file       date  \
# ...

# %%
# DAU/ WAU/ MAU — количество уникальных пользователей в день/ неделю/ месяц

dau = (data.groupby('first_date').agg({'customer':'nunique'}).mean())

wau = (data.groupby(['first_week']).agg({'customer': 'nunique'}).mean())

mau = (data.groupby(['first_month']).agg({'customer': 'nunique'}).mean())

print(f'''DAU: {int(dau)}
WAU: {int(wau)}
MAU: {int(mau)}''')
# Out:
# DAU: 15
# WAU: 105
# MAU: 456

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Выводы:</b>
#
# Люди совершают пожертвование хотя бы раз в месяц (MAU: 456), но далеко не каждый день (DAU: 15). В целом это нормально, если учитывать характер ежемесячной подписки.
#
# Но встаёт вопрос: насколько активно они покупают продукцию, созданную в мастерских? Возможно стоит чуть лучше изучить ЦА и её интересы и на этой основе доработать продаваемую продукцию.
#
# </div>

# %%
# отражает регулярность использования сервиса или приложения
sticky_factor_w = dau/wau
sticky_factor_m = dau/mau

print(f'''sticky factor, week: {float(sticky_factor_w)*100}
sticky factor, month: {float(sticky_factor_m)*100}''')
# Out:
# sticky factor, week: 14.851400625072348
# sticky factor, month: 3.4239107954310426

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Выводы:</b>
#
# Значения sticky factor (неделя — 14.85, месяц — 3.42) подтверждают, что пользователи действительно вовлечены в продукт. Высокий sticky factor на недельной основе указывает на надежную базу активных пользователей.
#  </div>

# %%
# сколько в среднем сессий приходится на одного пользователя в месяц
sessions_per_user_m = data.groupby(['first_month']).agg(
    {'customer': ['count', 'nunique']}
)

# переименовываем колонки
sessions_per_user_m.columns = ['n_sessions', 'n_users']

# делим число сессий на количество пользователей
sessions_per_user_m['sessions_per_user_m'] = (sessions_per_user_m['n_sessions'] / sessions_per_user_m['n_users'])

sessions_per_user_m
# Out:
#              n_sessions  n_users  sessions_per_user_m
# first_month
# 1                   256      251             1.019920
# 2                   248      242             1.024793
# 3                   302      283             1.067138
# 4                   289      274             1.054745
# 5                   557      523             1.065010
# 6                  1012      982             1.030550
# 7                   662      638             1.037618

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Выводы:</b>
#
# В месяц один пользователь в среднем совершает максимум одно пожертвование. Неплохой показатель, учитывая специфику.
#  </div>

# %%
# сколько в среднем сессий приходится на одного пользователя в неделю
sessions_per_user_w = data.groupby(['first_week']).agg(
    {'customer': ['count', 'nunique']}
)

# переименовываем колонки
sessions_per_user_w.columns = ['n_sessions', 'n_users']

# делим число сессий на количество пользователей
sessions_per_user_w['sessions_per_user_w'] = (sessions_per_user_w['n_sessions'] / sessions_per_user_w['n_users'])

sessions_per_user_w
# Out:
#             n_sessions  n_users  sessions_per_user_w
# first_week
# 1                   55       53             1.037736
# 2                   83       83             1.000000
# 3                   65       64             1.015625
# 4                   48       48             1.000000
# 5                   51       49             1.040816
# 6                   58       58             1.000000
# 7                   75       73             1.027397
# 8                   45       45             1.000000
# 9                   67       67             1.000000
# 10                  53       53             1.000000
# 11                  85       84             1.011905
# 12                  68       63             1.079365
# 13                  53       49             1.081633
# 14                  64       61             1.049180
# 15                  89       87             1.022989
# 16                  72       70             1.028571
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Выводы:</b>
#
# Схожая ситуация и в неделю.
#  </div>

# %% [markdown]
# #### Дополнительно

# %% [markdown]
# Изучим проблемы с платежами.

# %%
full_data.groupby('order_id')['status'].apply(list).value_counts()
# Out:
# status
# [Завершена]                                                1127
# [Отклонена]                                                  44
# [Завершена, Отклонена]                                       37
# [Отклонена, Отклонена]                                       11
# [Завершена, Отклонена, Отклонена]                             3
# [Отклонена, Отклонена, Отклонена, Отклонена, Отклонена]       1
# Name: count, dtype: int64

# %%
# Сначала группируем данные и создаём список статусов для каждого order_id
grouped_status = full_data.groupby('order_id')['status'].apply(list)
# Также поступаем с названиями файлов, которые названы по месяцам года
grouped_months = full_data.groupby('order_id')['file'].apply(list)

# Создаём DataFrame-ы из списков статусов и месяцев, чтобы проще анализировать данные
statuses_df = pd.DataFrame(grouped_status).reset_index()
months_df = pd.DataFrame(grouped_months).reset_index()

# Объединяем их
full_df = statuses_df.merge(months_df, on='order_id', how='left')

full_df['rejected_count'] = full_df['status'].apply(lambda x: x.count('Отклонена'))

result = full_df[full_df['rejected_count'] >= 2]

result
# Out:
#         order_id                                             status  \
# 244      21138.0                             [Отклонена, Отклонена]
# 423      21367.0                             [Отклонена, Отклонена]
# 436      21385.0                             [Отклонена, Отклонена]
# 496      21482.0                  [Завершена, Отклонена, Отклонена]
# 531      21550.0                             [Отклонена, Отклонена]
# 652      21726.0                  [Завершена, Отклонена, Отклонена]
# 701      21849.0                  [Завершена, Отклонена, Отклонена]
# 817      22048.0                             [Отклонена, Отклонена]
# 845      22147.0                             [Отклонена, Отклонена]
# 981      22346.0                             [Отклонена, Отклонена]
# 1020     22390.0                             [Отклонена, Отклонена]
# 1182     23034.0                             [Отклонена, Отклонена]
# 1216   2470947.0                             [Отклонена, Отклонена]
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Выводы:</b>
#
# Больше всего повторных отклонений было в мае, июне и июле. Возможно в тот момент были сбои с платёжными системами.
#
#  </div>

# %% [markdown]
# Изучим все отменённые транзакции по иностранным картам.

# %%
test = (full_data.loc[full_data['operation_currency'] != 'RUB']).copy()
display(test.sample(5))
print('Пожертвований в иностранной валюте:', len(test))
# Out:
#               id action_date      bank              site  order_id  \
# 2640  2117002700         NaT  Тинькофф  prostieveschi.ru   21385.0
# 1250  2109670655         NaT  Тинькофф  prostieveschi.ru   20515.0
# 721   2119105759         NaT  Тинькофф  prostieveschi.ru   21896.0
# 2852  2116331350         NaT  Тинькофф  prostieveschi.ru   21145.0
# 2641  2117002552         NaT  Тинькофф  prostieveschi.ru   21385.0
#
#                        customer    type  operation_sum operation_currency  \
# 2640        dasha90****@mail.ru  Оплата             50                BYN
# 1250  junipher.gr****@gmail.com  Оплата              1                EUR
# 721        alex.s****@gmail.com  Оплата            200                USD
# 2852       nastya****@yandex.ru  Оплата              3                USD
# 2641        dasha90****@mail.ru  Оплата             50                BYN
#
#       comission_sum  final_sum final_currency     status  \
# ...

# %% [markdown]
# Посмотрим сколько из них прошли успешно.

# %%
(test['status']).value_counts()
# Out:
# status
# Отклонена    26
# Name: count, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Выводы:</b>
#
# Все отклонены. Похоже какая-то ошибка с принятием иностранных карт.
#
# Разведка показала, что иностранной картой можно внести пожертвование путём покупки сертификата на Озон. Возможно с их стороны какая-то ошибка.
#
#  </div>

# %% [markdown]
# Посмотрим на транзакции по картам в российских рублях.

# %%
test_2 = (full_data.loc[full_data['operation_currency'] == 'RUB']).copy()
display(test_2.sample(5))
print('Пожертвований в рублях:', len(test_2))
# Out:
#               id         action_date      bank              site  order_id  \
# 3229  2112711156 2024-05-08 12:13:00  Тинькофф  prostieveschi.ru   20699.0
# 130   2121494322 2024-06-27 15:49:00  Тинькофф  prostieveschi.ru       NaN
# 3158  2113499713                 NaT  Тинькофф  prostieveschi.ru       NaN
# 3381  2126691152 2024-07-28 22:59:00  Тинькофф  prostieveschi.ru       NaN
# 2772  2116456847 2024-05-28 14:06:00  Тинькофф  prostieveschi.ru   21237.0
#
#                     customer               type  operation_sum  \
# 3229     Bar-m****@yandex.ru             Оплата          20000
# 130   alisatia****@gmail.com  Регулярная оплата            500
# 3158       aalpa****@list.ru  Регулярная оплата            100
# 3381     balak****@gmail.com  Регулярная оплата           3000
# 2772   umalysh****@gmail.com             Оплата           1000
#
#      operation_currency  comission_sum  final_sum final_currency     status  \
# ...

# %%
(test_2['status']).value_counts()
# Out:
# status
# Завершена    3327
# Отклонена     795
# Name: count, dtype: int64

# %%
round(795 / 4122 * 100, 1)
# Out:
# 19.3

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Выводы:</b>
#
# Из 4122 пожертвования 795 были отклонены. Не должно быть таких сложностей как с иностранной картой, тем не менее, было утеряно это 19,3%.
#
#  </div>

# %%
# выберем все отклонённые транзакции
full_data_declined = full_data.loc[full_data['status'] == 'Отклонена']

# выберем первое неудавшееся пожертвование у каждого пользователя
total_declined_money = full_data_declined.groupby(['file', 'customer','operation_currency']).agg({'customer':'first', 'operation_sum':'first'})

# просуммируем неудавшиеся пожертвования по валюте
declined_money = total_declined_money.groupby('operation_currency').agg({'operation_sum':'sum'})

# переведём в рубли по курсу на 18.02.2025
declined_money['final'] = declined_money['operation_sum']
declined_money['final'].iloc[0] = (declined_money['final'].iloc[0]).astype('int') * 27.98 #BYN
declined_money['final'].iloc[1] = (declined_money['final'].iloc[1]).astype('int') * 95.77 #EUR
declined_money['final'].iloc[3] = (declined_money['final'].iloc[3]).astype('int') * 91.65 #USD

declined_money.columns = declined_money.columns=['currency', 'RUB']

display(declined_money)

print('Утеряно денег из-за отмен:', declined_money['RUB'].sum(), 'RUB')
print('Из них с иностранных карт:', round(declined_money['RUB'].sum() - declined_money['RUB'].iloc[2], 2), 'RUB')
# Out:
#                     currency        RUB
# operation_currency
# BYN                       60    1678.80
# EUR                      164   15706.28
# RUB                   334068  334068.00
# USD                      343   31435.95
# Утеряно денег из-за отмен: 382889.03 RUB
# Из них с иностранных карт: 48821.03 RUB

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Выводы:</b>
#
# Потеря пожертвований с иностранных карт неприятна, но больший масштаб проблемы — это отклонённые пожертвоания с российских карт.
#
#  </div>

# %%
a = data.file.value_counts().reset_index()
a.columns = a.columns=['month', 'завершена_cnt']
b = full_data_declined.file.value_counts().reset_index()
b.columns = b.columns=['month', 'отклонена_cnt']

# %%
ab = a.merge(b, on='month', how='left')
ab['month'].iloc[0] = 6
ab['month'].iloc[1] = 7
ab['month'].iloc[2] = 5
ab['month'].iloc[3] = 3
ab['month'].iloc[4] = 4
ab['month'].iloc[5] = 1
ab['month'].iloc[6] = 2
ab = ab.sort_values(by='month').reset_index(drop=True)
ab
# Out:
#   month  завершена_cnt  отклонена_cnt
# 0     1            256             79
# 1     2            248             90
# 2     3            302             98
# 3     4            289            105
# 4     5            557            131
# 5     6           1012            151
# 6     7            662            167

# %%
plt.figure(figsize=(5, 10))

ax = ab.sort_values(by='month').plot(x='month', grid=True)

ax.set_title('График распределения количества транзакций со статусами "Завершена" и "Отклонена"')
ax.set_xlabel('Месяц')
plt.yticks(range(0, 1100, 200))

plt.show()

# %% [markdown]
# Выявлены два необычных, по характеру оплаты, пользователя.

# %%
full_data.loc[full_data['customer'] == 'morozov****@list.ru']
# Out:
#               id         action_date      bank              site  order_id  \
# 1239  2109897510 2024-04-24 14:04:00  Тинькофф  prostieveschi.ru   20528.0
# 1254  2109503360 2024-04-22 14:05:00  Тинькофф  prostieveschi.ru   20510.0
# 1301  2108677277 2024-04-18 14:17:00  Тинькофф  prostieveschi.ru   20463.0
# 1405  2107424495 2024-04-12 14:08:00  Тинькофф  prostieveschi.ru   20360.0
# 1503  2105709055 2024-04-04 14:13:00  Тинькофф  prostieveschi.ru   20240.0
# 1525  2105509333 2024-04-03 14:08:00  Тинькофф  prostieveschi.ru   20168.0
# 2243  2104371485 2024-03-29 14:15:00  Тинькофф  prostieveschi.ru   20117.0
# 2277  2103426398 2024-03-26 14:22:00  Тинькофф  prostieveschi.ru   20078.0
# 2285  2103104063 2024-03-25 14:38:00  Тинькофф  prostieveschi.ru   20070.0
# 2316  2102145923 2024-03-22 14:24:00  Тинькофф  prostieveschi.ru   20038.0
# 2344  2101457589 2024-03-20 14:08:00  Тинькофф  prostieveschi.ru   20006.0
# ...

# %% [markdown]
# Платит практически в одно и тоже время по 300 руб с марта по май. В мае каждые 1-5 дней. Что он может покупать?

# %%
full_data.loc[full_data['customer'] == 'k_****@inbox.ru']
# Out:
#               id         action_date      bank              site  order_id  \
# 703   2119152381 2024-06-13 12:29:00  Тинькофф  prostieveschi.ru       NaN
# 783   2118985016                 NaT  Тинькофф  prostieveschi.ru       NaN
# 800   2118894512 2024-06-11 21:02:00  Тинькофф  prostieveschi.ru       NaN
# 852   2118720879                 NaT  Тинькофф  prostieveschi.ru       NaN
# 1384  2107614471 2024-04-13 12:28:00  Тинькофф  prostieveschi.ru       NaN
# 1408  2107405532                 NaT  Тинькофф  prostieveschi.ru       NaN
# 1425  2107292819 2024-04-11 21:02:00  Тинькофф  prostieveschi.ru       NaN
# 1453  2107081450                 NaT  Тинькофф  prostieveschi.ru       NaN
# 1734  2070720884 2024-01-10 21:01:00  Тинькофф  prostieveschi.ru       NaN
# 2027  2086037420 2024-02-12 12:28:00  Тинькофф  prostieveschi.ru       NaN
# 2061  2085317839 2024-02-10 21:01:00  Тинькофф  prostieveschi.ru       NaN
# ...

# %% [markdown]
# Платит стабильно по 1000 руб с января по февраль дважды в месяц в районе 10-12 числа в 21:02 и в 12:28 соответственно. В июне и апреле даты и время слегка сдвинулись. Он оформил два раза подписку? Почему в июне и апреле произошёл сдвиг по времени?

# %% [markdown]
# ## Общие выводы, важное

# %% [markdown]
# ### RFM

# %% [markdown]
# **Recency**:
# - **1**, 90+: давние пожертвования.
# - **2**, 30-90: относительно недавние пожертвования, 1-3 месяца.
# - **3**, 0-30: те, кто жертвовал недавно, 1 месяц (также могут быть те, кто жертвуют раз в месяц по ежемесячной подписке).
#
# **Frequency**:
# - **1**, 0-3: жертвовали редко.
# - **2**, 3-8: жертвовали несколько раз.
# - **3**, 8+: много пожертвований.
#
# **Monetary**:
# - **1**, 0-500: маленькая сумма пожертвований.
# - **2**, 500-3000: небольшая/ средняя сумма пожертвований.
# - **3**, 3000+: большая сумма пожертвований.

# %%
plt.figure(figsize=(15,5))

order = rfm_tab['rfm'].value_counts().index
# order = rfm_tab['rfm'].sort_values().unique() - лексикографический порядок
ax = sns.countplot(x = 'rfm', data = rfm_tab, order = order, palette='pastel')

ax.set_title('График распределения RFM')
ax.set_xlabel('RFM')

for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='bottom')

plt.show()

# %%
rfm__total_tab
# Out:
#     RFM  Кол-во жертвователей  Lifetime  Среднее пожертвование, руб  \
# 0   111                    53      5.04                      327.47
# 1   112                    27     27.19                     1158.01
# 2   113                     6      1.00                    30371.00
# 3   121                     1     92.00                      384.40
# 4   122                     2    107.00                     1790.80
# 5   123                     1     92.00                     3872.00
# 6   211                   440      1.51                      340.21
# 7   212                   272      5.13                     1160.89
# 8   213                    36      6.39                     9479.41
# 9   221                     3    140.67                      448.93
# 10  222                    14    156.50                     1406.09
# 11  223                     6    139.33                     8300.60
# 12  233                     2     67.00                     5227.20
# ...

# %% [markdown]
# <b>Топ-10 категорий по суммам пожертвований.</b>

# %%
rfm_tab.groupby('rfm')['total_final_sum'].sum().sort_values(ascending=False).nlargest(10)
# Out:
# rfm
# 323    591244.72
# 213    341258.72
# 212    315762.14
# 312    285382.42
# 322    195439.60
# 113    182226.00
# 211    149693.37
# 313    106964.00
# 333     95658.99
# 223     49803.60
# Name: total_final_sum, dtype: float64

# %% [markdown]
# <b>Топ-10 жертвователей, внёсших самые больше суммы.</b>

# %%
rfm_tab.groupby('customer')['total_final_sum'].sum().sort_values(ascending=False).nlargest(10)
# Out:
# customer
# humblehelptope****@gmail.com    145200.00
# Bar-m****@yandex.ru              77440.00
# n-sorokina@yandex.ru             49368.00
# azat.khali****@gmail.com         48400.00
# avito****@hotmail.com            38720.00
# jevge****@bk.ru                  33880.00
# ket****@mail.ru                  33880.00
# holo****@gmail.com               28739.92
# hel****@mail.ru                  25168.00
# art.ma****@gmail.com             23716.00
# Name: total_final_sum, dtype: float64

# %% [markdown]
# <b>Топ-10 категорий по количеству жертвователей.</b>

# %%
rfm_tab.groupby('rfm')['customer'].nunique().sort_values(ascending=False).nlargest(10)
# Out:
# rfm
# 211    440
# 212    272
# 312    223
# 311    152
# 322    126
# 323     77
# 111     53
# 213     36
# 112     27
# 222     14
# Name: customer, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# Наибольшую часть пожертвований приносят следующие группы:
# - 323: 591244.72 руб.
# - 213: 341258.72 руб.
# - 212: 315762.14 руб.
# - 312: 285382.42 руб.
# - 322: 195439.60 руб.
#
# Группа жертвующая небольшие суммы, но тем не менее наиболее многочисленная. Поэтому очень важная.
# - 211: 149693.37 руб.
#
# Группа людей, которые жертвовали давно, редко, но большие суммы. Можно как-то их "разбудить".
# - 113: 182226.00 руб.
#
# А непосредственно человека с e-mail: humblehelptope****@gmail.com. Он пожертвовал 145200.00 руб.
#
# </div>

# %% [markdown]
# ### Когортный анализ и Маркетинговый анализ

# %% [markdown]
# 1. Отличное удержание клиентов и доходность:
#    - Retention Rate в когортах из первого месяца (январь 2024 года) показывает высокий уровень удержания, что подтверждается высокой оценкой ARPU (3267.37). Это говорит о том, что клиенты не только остаются, но и приносят значительный доход.
#    - В то время как для других когорт (например, для февраля) ARPU ниже (2032.57) при значительно меньшем retention rate, что может указывать на проблемы с качеством сервиса или недостаток вовлеченности.
#
# 2. Непостоянство ARPU:
#    - ARPU варьируется от 1053.84 до 4818.30, что указывает на различия в доходности между когортами. Особенно выражен этот разрыв в первой десятке (март 2024) и июне 2024 года. Такие различия могут быть связаны как с активностью пользователей, так и с ценовыми стратегиями.
#
# 3. LTV как долгосрочный показатель:
#    - За все когортные данные LTV показывает общий положительный тренд, достигая 1665.52 к последнему месяцу. Это отражает в целом успешное удержание клиентов и их отношение к компании.
#
# 4. DAU, WAU и MAU:
#    - Результаты показателей DAU (15), WAU (105) и MAU (456) указывают на активность пользователей, хотя и не такие высокие как могли бы быть. Эти числа показывают, что аудитория активная, но не настолько значительная для достижения больших результатов.
#
# 5. Sticky Factor:
#    - Значения sticky factor (неделя — 14.85, месяц — 3.42) подтверждают, что пользователи действительно вовлечены в продукт. Высокий sticky factor на недельной основе указывает на надежную базу активных пользователей.
#
# 6. Среднее количество сессий на пользователя в месяц:
#    - С увеличением числа месяцев, наблюдается маленький, но положительный тренд в средней сессии на пользователя (например, 1.03-1.07). Это говорит о том, что пользователи становятся более вовлеченными.
#
# 7. Улучшение стратегии удержания:
#    - Сравнивая показатели retention rate, ARPU и LTV, следует сосредоточиться на улучшении обучения клиентов и дачи им ценности, что поможет повысить общий уровень удержания и доходности.
#
# В итоге, хотя retention rate и ARPU в разных когорт показывают различия, в целом есть положительные тренды, которые могут быть усилены дальнейшей аналитикой и улучшением клиентского опыта.

# %% [markdown]
# ### Дополнительно

# %% [markdown]
# - 19.82% исходных данных утеряно в ходе обработки. Это всё отклонённые транзакции.
#
# - Больше всего повторных отклонений было в мае, июне и июле. Возможно в тот момент были сбои с платёжными системами.
#
# - Похоже какая-то ошибка с принятием иностранных карт. Все транзакции по ним отменены. Разведка показала, что иностранной картой можно внести пожертвование путём покупки сертификата на Озон. Возможно с их стороны какая-то ошибка.
#
# - Интересный пик пожертвования был 22 июня 2024. Исследование каналов Простых вещей показало, что в этот день была встреча с основательницей «Простых вещей» Машей Грековой в Москве. Возможно это как-то побудило людей направить в фонд деньги. Пик в основном составляет тип оплаты "Оплата".

# %%
display(declined_money)

print('Утеряно денег из-за отмен:', declined_money['RUB'].sum(), 'RUB')
print('Из них с иностранных карт:', round(declined_money['RUB'].sum() - declined_money['RUB'].iloc[2], 2), 'RUB (по курсу на 18.02.2025)')
# Out:
#                     currency        RUB
# operation_currency
# BYN                       60    1678.80
# EUR                      164   15706.28
# RUB                   334068  334068.00
# USD                      343   31435.95
# Утеряно денег из-за отмен: 382889.03 RUB
# Из них с иностранных карт: 48821.03 RUB (по курсу на 18.02.2025)

# %% [markdown]
# ## Аналитическая панель

# %% [markdown]
# Приложение в streamlit: https://sipmle-things-bhuipj98x34ws8kuillic2.streamlit.app/?embed_options=light_theme

# %% [markdown]
# Ссылка на репозиторий: https://github.com/LKonyukova/Sipmle-things
